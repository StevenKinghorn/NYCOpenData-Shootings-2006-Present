# %% [markdown]
# # Report

# %% [markdown]
# **NOTES:**
# - Added a day_or_night column [Need to explain how these are generated]
# - Merged victims dataset to shootings - aggregated victim and death count

# %% [markdown]
# - 75th Precinct - Highest Number of Shootings in NYC in years 2023-2025 but that number is falling

# %% [markdown]
# ## Max deaths and Victims Frequency over last 20 years
# - The highest number of deaths/murders for any one shooting over the last 20 years is 4 (highest victim count is 14)
#     - 2 cases:
#         - BAR/NIGHT CLUB in BROOKLYN on Sat morning at 6:55am 12th Oct 2019 there were 7 total victims 4 of which died.
#         - Unknown exact location but was COMMERCIAL in MANHATTAN on Monday evening 6:28pm 28th July 2025, there were 5 total victims 4 of which died.
#     - Need to do a bar chart of count of deaths per shooting and victims per shooting to show how common deaths and victims are per shooting.

# %% [markdown]
# ## City-Wide Shooting and Death counts per Year and per Quarter over 20 Years
# - Shootings remained consistent from 2006 to 2011 then gradually decreased from 2012 until 2020 and 2021 where they spiked higher than any time in the last 20 years - **What's the rate of decrease (gradient) from  2011-2019 amd 2021-2025?**
# - The lowest shootings and deaths, city-wide, occured between the years 2017 and 2019 and 2025 following spike during pandemic and George Floyd protests
# - Between 2019 and 2020, there was a 197.2% increase in total yearly shootings city-wide in NYC.
# And, there was a 189.6% increase in deaths city-wide in NYC
# - Fairly consistent pattern here city-wide over past twenty years
#     -  Q1 consistently shows the lowest shooting occurance with only Q4 of 2025 matching Q1 of 2026
#     -  Q3 has the highest rate of shootings for 19 out of the 20 years with the exception of 2021 where Q2 had a slight increase over Q3 of the same year.
#     -  These patterns persist even when the total shooting counts change throughout the two decades
#     -  Deaths show a more random or unpredictible pattern compared to shooting incidents probably due to more factors influencing these events like proximity of shooter to victim, number of shots fired, weapon used, proximity to hospital etc.
#     -  But, there tends to be more death by shooting city-wide in Q3 and a reduction in Q1.
#     -  in 20 years of data, the highest shootings and death count was in Q3 of 2020 where 634 shootings took place with 131 deaths as a result of gun violence in NYC. A number of things could have contributed to this during this time including pandemic, George Floyd Protests, NYC bail reforms but more extensive analysis would need to be done to confidently link these factors to the increase in gun violence.

# %% [markdown]
# ## Shooting and Deaths broken down by Borough (2017 - 2025) **Raw counts**
# - Closer look at pre, during and post pandemic
# - every borough in NYC saw an increase in shootings in 2020 compared to the previous year (show percentage increase) with Brooklyn, Queens and Staten Island peaking in 2020 before declining and The Bronx and Manhatten continuing to climb into 2021 before decline in the years after.
# - Dealing with raw counts so cannot conclude why counts reduced from 2021

# %% [markdown]
# ## Shooting & Death __Rate__ per Borough in 2020
# ##### shootings per 100'000 people from 2020 decennial census count https://popfactfinder.planning.nyc.gov/
# - Cencus count was concluded on 1st April 2020
# - Which borough was more dangerous in 2020?
# - No association between population density and shooting or death rate per 100'000
# - Shootings per 100k were ...% and ...% higher in The Bronx and Brooklyn respectively. At arounf 25 shooting occurances per 100k
# - Manhatten showed far fewer shooting occurances per 100k (about 13-7 per 100k)
# - Death rate per 100k, however, seemed to be more common in Brooklyn, then The Bronx followed by Staen Island (Must explain why - maybe low death count?)
# - **Maybe, I can compare the deaths to shootings rate here too?**
# -

# %% [markdown]
# ## Ratio of Inside/Outside City-Wide Per Year (2017–2025)
# - Only focus on city-wide shooting by year due to small sample size for Staten Island
# - COmplare the ration between Inside and outside per year especially during pandemic times
# - Also explain what OUTSIDE/INSIDE means

# %% [markdown]
# ## Ratio of Day/Night Shootings City-Wide Per Year (2017–2025)
# - Less shootings at night but still higher shootings per day
# - Could break down by borough

# %% [markdown]
# ## Shootings by Hour of Day in 2025 City-Wide

# %% [markdown]
# ## Which Day of Week Has More Shootings City-Wide?

# %% [markdown]
# ## Precinct with Highest number of Shootings and Deaths over last 3 years

# %% [markdown]
# ## Limitations with Dataset
# - if exact GPS coordinates unknown, they are geoloacted to the nearest precint station house
#     - This results in a cluster of points in a location where these shootings did not take place
